# %%
## Find out if gross is affected by budget
# Import libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots we will create

# Read data
df = pd.read_csv(r'C:\Users\User\OneDrive\Desktop\Data Analytics\Portfolio\Excel\movies.csv')

# %%
# View Data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Check if there is any existing missing values
df.isna().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Drop rows with missing values
df1 = df.dropna()

# %%
# Check if any mixxing values still exist
df1.isna().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
# Check datatypes
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Split released column 
df1[['Month', 'Day', 'Year_correct', 'Country']] = df1['released'].str.split(n = 3, expand = True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_980\3576951126.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['Month', 'Day', 'Year_correct', 'Country']] = df1['released'].str.split(n = 3, expand = True)
# C:\Users\User\AppData\Local\Temp\ipykernel_980\3576951126.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['Month', 'Day', 'Year_correct', 'Country']] = df1['released'].str.split(n = 3, expand = True)
# ...

# %%
df1.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Drop unwanted columns which are yearcorrect, month, day, country
df1 = df1.drop(['Month', 'Day', 'Country'], axis=1)

# %%
# Sort data by gross
df1.sort_values(by=['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# Set rows to none so we can observe the whole table
pd.set_option('display.max_rows', 30)

# %%
# Checking distinct count

df1['company'].drop_duplicates().sort_values(ascending = False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
# Check Correlation on budget versus gross
# First use scatter plot to toughly analyse if it is correlated

plt.scatter(x = df1['budget'], y = df1['gross'])
plt.title("Budget vs Gross Earnings")
plt.xlabel('Budget for film')
plt.ylabel('Gross Earnings')

#plot seems to be slightly correlated, we will progress with regplot to verify
# Out:
# Text(0, 0.5, 'Gross Earnings')

# %%
# Plot budget vs gross using seaborn

sns.regplot(x = 'budget', y = 'gross', data=df1, scatter_kws= {"color": "red"}, line_kws = {"color": "blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Start looking at correlation between each variables
# Default methods will be pearson, alternatives are kendall and spearman
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
# Higher correlation between budget and gross observed

# %%
# We will be using a correlation heatmap for us to identify higher correlated variables against our dependent variable budget
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Budget for Film')
plt.show()

# %%
# Look at Variable "Company" by turning it into a numeric variable.
# By logic if the film is created by a bigger studio, it should be able to provide higher budgets and gross
# Using pd.DataFrame will not affect df1 when we run through the for loop

df_numerized = pd.DataFrame(df1)

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1     3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2     3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3      204       4      4  1980      1127    7.7   221000.0       889    1413
# 4      732       6      4  1980      1170    7.3   108000.0       719     351
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   415       6      0  2020       904    6.6   140000.0        16    2390
# 7649  3556       4      0  2020       713    6.5   102000.0       852    2309
# 7650  1153       4      1  2020       904    5.6    53000.0      1809    2827
# 7651  3978       4      1  2020       758    6.8    42000.0       294    2091
# 7652  4090       3      0  2020       370    6.8     3700.0       746    1184
#
# ...

# %%
# We can now do a simple correlation analysis between all features

correlation_matrix1 = df_numerized.corr()
sns.heatmap(correlation_matrix1, annot = True)
plt.title('Correlation for all features')
plt.xlabel('Movie Features')
plt.ylabel('Budget')
plt.show()

# %%
df_numerized.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating       -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre         0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year          0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released     -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score         0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes         0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director      0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer        0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star         -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country      -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget        0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.029234
#               genre           0.010996
#               year            0.025542
#               released       -0.006152
#                                 ...
# Year_correct  budget          0.320216
#               gross           0.268367
#               company        -0.016150
#               runtime         0.076203
#               Year_correct    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(ascending = False)
sorted_pairs
# Out:
# name     name       1.000000
# rating   rating     1.000000
# runtime  runtime    1.000000
# company  company    1.000000
# gross    gross      1.000000
#                       ...
# budget   rating    -0.203946
# gross    genre     -0.244101
# genre    gross     -0.244101
# budget   genre     -0.368523
# genre    budget    -0.368523
# Length: 256, dtype: float64

# %%
# Identify highly correlated pairs that are > 0.5
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# name          name            1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# Year_correct  Year_correct    1.000000
#               year            0.994821
# year          Year_correct    0.994821
# budget        gross           0.740247
# gross         budget          0.740247
#               votes           0.614751
# votes         gross           0.614751
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings for films
